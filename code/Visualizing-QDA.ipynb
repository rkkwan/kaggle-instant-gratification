# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
xmin = -4
xmax = 4
ymin = -4
ymax = 4

xres = 100
yres = 100
xx = np.linspace(xmin,xmax,xres)
yy = np.linspace(ymin,ymax,yres)
grid = np.zeros((xres*yres,2))
for i in range(yres):
    grid[i*xres:(i+1)*xres,0] = xx
for i in range(yres):
    for j in range(xres):
        grid[i*xres+j,1] = yy[i]

# %%
plt.plot(grid)
# Out:
# [<matplotlib.lines.Line2D at 0x11e53d198>,
#  <matplotlib.lines.Line2D at 0x11e53d390>]

# %%
clf = QuadraticDiscriminantAnalysis()
clf.fit(X,y)
preds = clf.predict(grid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a7b6d18592c6> in <module>()
#       1 clf = QuadraticDiscriminantAnalysis()
# ----> 2 clf.fit(X,y)
#       3 preds = clf.predict(grid)
#
# NameError: name 'X' is not defined
